# %%
import pandas
pd = pandas.read_excel(r"\\Pc-201904292001\渝北项目成果文件-余勇(勿删！！)\0登记中心成果汇交！！\石船镇\数据库及台账\重桥村\存量成果台账\渝北区石船镇重桥村存量成果台账（已上图）.xlsx")
jzcmj=list(pd["房屋超建说明"].notnull())
zdcmj=list(pd["宗地超占说明"].notnull())
zddm=list(pd["宗地代码"])
a={}
for i in range(len(jzcmj)):
    a[zddm[i]]=(jzcmj[i] and not zdcmj[i])

print(a)
# Out:
# {'500112142202JC00576': False, '500112142202JC00577': False, '500112142202JC00578': False, '500112142202JC00579': True, '500112142202JC00580': False, '500112142202JC00581': False, '500112142202JC00582': False, '500112142202JC00583': False, '500112142202JC00584': False, '500112142202JC00585': False, '500112142202JC00586': False, '500112142202JC00587': False, '500112142202JC00588': False, '500112142202JC00589': False, '500112142202JC00590': False, '500112142202JC00591': False, '500112142202JC00592': False, '500112142202JC00593': False, '500112142202JC00594': False, '500112142202JC00595': False, '500112142202JC00597': False, '500112142202JC00598': False, '500112142202JC00599': False, '500112142202JC00600': False, '500112142202JC00601': False, '500112142202JC00602': False, '500112142202JC00603': False, '500112142202JC00604': True, '500112142202JC00605': True, '500112142202JC00606': False, '500112142202JC00607': False, '500112142202JC00608': False, '500112142202JC00609': False, '500112142
# ...

# %%
a = False or True
